# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install simpleitk
# Out:
# Collecting simpleitk
#   Downloading SimpleITK-2.1.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 32 kB/s
# Installing collected packages: simpleitk
# Successfully installed simpleitk-2.1.0

# %%
import SimpleITK as sitk
import numpy as np
import cv2
import os

def mha2png(mhaPath,outFolder,windowsCenter,windowsSize):
    
    """
    The function can output a group of png files by a specified mha file.
    Args:
        mhaPath:mha file path.
        outfolder:The folder that the png files are saved.
        windowsCenter:the CT windows center.
        windowsSize:the CT windows size.
    Return:void

    """
    image = sitk.ReadImage(mhaPath)
    img_data = sitk.GetArrayFromImage(image)
    channel = img_data.shape[0]

    if not os.path.exists(outFolder):
        os.makedirs(outFolder)


    low = windowsCenter-windowsSize/2
    high = windowsCenter+windowsSize/2

    for s in range(channel):
        slicer = img_data[s,:,:]
        slicer[slicer<low] = low
        slicer[slicer>high] = high
        slicer = slicer-low
        img = cv2.normalize(slicer, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
        cv2.imwrite(os.path.join(outFolder,'P211_'+str(s)+'_T2F_HGG_T.png'),img)

def main():
    mha = input("Enter the mha path:")
    out = input("Enter the out folder:")
    wc = int(input("Enter the windows center:"))
    ws = int(input("Enter the windows size:"))
    mha2png(mha,out,wc,ws)



if __name__ == "__main__":
    main()
# Out:
# Enter the mha path:/content/gdrive/MyDrive/EE657 Research/BRATS2015/BRATS2015_Training/BRATS2015_Training/HGG/brats_tcia_pat211_0001/VSD.Brain.XX.O.MR_Flair.35736/VSD.Brain.XX.O.MR_Flair.35736.mha
# Enter the out folder:/content/gdrive/MyDrive/EE657 Research/BRATS Images/All_T2_Flair/Train_7
# Enter the windows center:400
# Enter the windows size:1200
